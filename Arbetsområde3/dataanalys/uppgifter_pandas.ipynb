# %%
# Uppgift 1

import matplotlib.pyplot as plt 
import pandas as pd

df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)

df
# Out:
#           sysselsättning     ålder      kön    2019
# 0      förvärvsarbetande  16-19 år      män   58826
# 1      förvärvsarbetande  16-19 år  kvinnor   72847
# 2      förvärvsarbetande  20-24 år      män  192696
# 3      förvärvsarbetande  20-24 år  kvinnor  174074
# 4      förvärvsarbetande  25-29 år      män  293352
# 5      förvärvsarbetande  25-29 år  kvinnor  268587
# 6      förvärvsarbetande  30-34 år      män  303019
# 7      förvärvsarbetande  30-34 år  kvinnor  271975
# 8      förvärvsarbetande  35-39 år      män  280522
# 9      förvärvsarbetande  35-39 år  kvinnor  255391
# 10     förvärvsarbetande  40-44 år      män  275085
# 11     förvärvsarbetande  40-44 år  kvinnor  260093
# 12  ej förvärvsarbetande  16-19 år      män  176860
# 13  ej förvärvsarbetande  16-19 år  kvinnor  143432
# 14  ej förvärvsarbetande  20-24 år      män  117928
# 15  ej förvärvsarbetande  20-24 år  kvinnor  103001
# 16  ej förvärvsarbetande  25-29 år      män   86633
# ...

# %%
# 1a:
import matplotlib.pyplot as plt 

lista_df = df[df["sysselsättning"]=="förvärvsarbetande"]
antal_df = lista_df["2019"].tolist()

antal = sum(antal_df)

print(f"{antal} är förvärvsarbetande år 2019")
# Out:
# 2706467 är förvärvsarbetande år 2019

# %%
# 1b:
import matplotlib.pyplot as plt 

lista2_df = df[df["sysselsättning"]=="ej förvärvsarbetande"]
antal2_df = lista2_df["2019"].tolist()

antal2 = sum(antal2_df)

print(f"{antal2} är ej förvärvsarbetade år 2019")
# Out:
# 1070645 är ej förvärvsarbetade år 2019

# %%
# 1c: 

import matplotlib.pyplot as plt 

andel = [antal, antal2]

my_labels = 'förvärvsarbetande', 'ej förvärvsarbetande'

plt.pie(andel, labels=my_labels, autopct='%1.1f%%')
plt.title("Andel förvärvsarbetande/ej förvärvsarbetande år 2019")
plt.axis("Equal")
plt.show()

# %%
# Uppgift 2

import pandas as pd

df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)

df
# Out:
#           sysselsättning     ålder      kön    2019
# 0      förvärvsarbetande  16-19 år      män   58826
# 1      förvärvsarbetande  16-19 år  kvinnor   72847
# 2      förvärvsarbetande  20-24 år      män  192696
# 3      förvärvsarbetande  20-24 år  kvinnor  174074
# 4      förvärvsarbetande  25-29 år      män  293352
# 5      förvärvsarbetande  25-29 år  kvinnor  268587
# 6      förvärvsarbetande  30-34 år      män  303019
# 7      förvärvsarbetande  30-34 år  kvinnor  271975
# 8      förvärvsarbetande  35-39 år      män  280522
# 9      förvärvsarbetande  35-39 år  kvinnor  255391
# 10     förvärvsarbetande  40-44 år      män  275085
# 11     förvärvsarbetande  40-44 år  kvinnor  260093
# 12  ej förvärvsarbetande  16-19 år      män  176860
# 13  ej förvärvsarbetande  16-19 år  kvinnor  143432
# 14  ej förvärvsarbetande  20-24 år      män  117928
# 15  ej förvärvsarbetande  20-24 år  kvinnor  103001
# 16  ej förvärvsarbetande  25-29 år      män   86633
# ...

# %%
# 2a:

import matplotlib.pyplot as plt 

förvärv_df = df[df["sysselsättning"]=="förvärvsarbetande"]
förvärv_män_df = förvärv_df[förvärv_df["kön"]=="män"]
lista1_df = förvärv_män_df["2019"].tolist()

sum1 = sum(lista1_df)

print(f"{sum1} män är förvärvsarbetande 2019 mellan åldern 16-44")
# Out:
# 1403500 män är förvärvsarbetande 2019 mellan åldern 16-44

# %%
# 2b:

import matplotlib.pyplot as plt 

förvärv_df = df[df["sysselsättning"]=="förvärvsarbetande"]
förvärv_kvinnor_df = förvärv_df[förvärv_df["kön"]=="kvinnor"]
lista2_df = förvärv_kvinnor_df["2019"].tolist()

sum2 = sum(lista2_df)

print(f"{sum2} kvinnor är förvärvsarbetande 2019 mellan åldern 16-44")
# Out:
# 1302967 kvinnor är förvärvsarbetande 2019 mellan åldern 16-44

# %%
# 2c:

import matplotlib.pyplot as plt 

ejförvärv_df = df[df["sysselsättning"]=="ej förvärvsarbetande"]
ejförvärv_män_df = ejförvärv_df[ejförvärv_df["kön"]=="män"]
lista3_df = ejförvärv_män_df["2019"].tolist()

sum3 = sum(lista3_df)

print(f"{sum3} män är ej förvärvsarbetande 2019 mellan åldern 16-44")
# Out:
# 545813 män är ej förvärvsarbetande 2019 mellan åldern 16-44

# %%
# 2d:

import matplotlib.pyplot as plt 

ejförvärv_df = df[df["sysselsättning"]=="förvärvsarbetande"]
ejförvärv_kvinnor_df = ejförvärv_df[ejförvärv_df["kön"]=="kvinnor"]
lista4_df = ejförvärv_kvinnor_df["2019"].tolist()

sum4 = sum(lista4_df)

print(f"{sum4} kvinnor är ej förvärvsarbetande 2019 mellan åldern 16-44")
# Out:
# 1302967 kvinnor är ej förvärvsarbetande 2019 mellan åldern 16-44

# %%
# 2e:

import matplotlib.pyplot as plt 

#kvinnor_df = df["kön"]=="kvinnor"
#kvinnor_värv = kvinnor_df[kvinnor_df["sysselsättning"]=="förvärvsarbetande"]
#kvinnor_ejvärv = kvinnor_df[kvinnor_df["sysselsättning"]=="ej förvärvsarbetande"]

#män_df = df["kön"]=="män"
#män_värv = män_df["sysselsättning"]=="förvärvsarbetande"
#män_ejvärv = män_df["sysselsättning"]=="ej förvärvsarbetande"

# fick inte ^ att fungera

# values kommer från tidigare uppgifter
# sum1 = antal män förvärvsarbetande
# sum2 = antal kvinnor förvärvsarbetande
# sum3 = antal män ej förvärvsarbetande
# sum4 = antal kvinnor ej förvärvsarbetande

labels = ["förvärv kvinnor", "ej förvärv kvinnor", "förvärv män", "ej förvärv män"]
values = [sum2, sum4, sum1, sum3]

plt.bar(labels, values, width=.4, color=["black", "green", "black", "green"])
plt.title("Sysselsättning i Sverige 2019")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Uppgift 3

import matplotlib.pyplot as plt 

män_df = df[df["kön"]=="män"]
värvmän_df = män_df[män_df["sysselsättning"]=="förvärvsarbetande"]

values_lista = värvmän_df["2019"].tolist()
labels_lista = värvmän_df["ålder"].unique()

plt.plot(labels_lista, values_lista)
plt.show()

# %%
# Uppgift 4

import pandas as pd

df = pd.read_csv("archive.csv")

df
# Out:
#      Year    Category                                           Prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 964  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 965  2016       Peace                      The Nobel Peace Prize 2016
# 966  2016     Physics                 The Nobel Prize in Physics 2016
# 967  2016     Physics                 The Nobel Prize in Physics 2016
# 968  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             Motivation Prize Share  \
# ...

# %%
# 4a:

sweden_df = df[df["Birth Country"]=="Sweden"]
values = sweden_df["Category"].value_counts().tolist()
labels = sweden_df["Category"].unique()


plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.show()

# %%
sweden_df
# Out:
#      Year    Category                                              Prize  \
# 13   1903   Chemistry                  The Nobel Prize in Chemistry 1903
# 48   1908       Peace                         The Nobel Peace Prize 1908
# 52   1909  Literature                 The Nobel Prize in Literature 1909
# 65   1911    Medicine     The Nobel Prize in Physiology or Medicine 1911
# 74   1912     Physics                    The Nobel Prize in Physics 1912
# 87   1916  Literature                 The Nobel Prize in Literature 1916
# 105  1921       Peace                         The Nobel Peace Prize 1921
# 121  1924     Physics                    The Nobel Prize in Physics 1924
# 128  1926   Chemistry                  The Nobel Prize in Chemistry 1926
# 155  1930       Peace                         The Nobel Peace Prize 1930
# 161  1931  Literature                 The Nobel Prize in Literature 1931
# 247  1948   Chemistry                  The Nobel Prize in Chemistry 1948
# ...
