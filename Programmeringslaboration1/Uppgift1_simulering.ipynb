# %%
# Uppgift 1a
import math # Använder denna modul för att kunna använda matte hjälpmedel
d = math.sqrt(0.5**2+0.5**2) # d = distance / math.sqrt = roten ur (med hjälp av import math)
print(d)
# Out:
# 0.7071067811865476

# %%
# Uppgift 1b
import math
d = math.sqrt(1**2+1**2) # d=distance
print(d)
# Out:
# 1.4142135623730951

# %%
# Uppgift 1c
import math
d = math.sqrt(0.5**2+(-0.5)**2) # d=distance
print(d)
# Out:
# 0.7071067811865476

# %%
# Uppgift 1d
import random as rnd # Använder denna modul för att kunna slumpa fram tal

n = 0 # Ett värde för variabeln som sedan ökas i for loopen

for i in range(100): # Hur många gånger loopen ska upprepas
    x = rnd.uniform(-1,1) # random generator
    y = rnd.uniform(-1,1) # random generator
    n += 1 # Vilken omgång det är, 1-100
    print(f"x{n} = {x}, y{n} = {y}") # f-string för att skriva ut text med variabel värdena
# Out:
# x1 = 0.2818257755263478, y1 = -0.7298505344744932
# x2 = -0.1531095108753444, y2 = -0.7484163939427406
# x3 = 0.0469221334031904, y3 = -0.6930583455515438
# x4 = 0.5893658156649912, y4 = 0.3802977649091568
# x5 = -0.6706353212415319, y5 = -0.16037175208992172
# x6 = -0.26768117366846167, y6 = -0.9861104033010379
# x7 = 0.7982941254376492, y7 = -0.22423289317801265
# x8 = -0.37239536601341316, y8 = -0.7373901243315493
# x9 = -0.7832632086819573, y9 = -0.07117255306795967
# x10 = 0.20492581548569944, y10 = 0.888165210723167
# x11 = -0.42225383005685413, y11 = -0.3549714293475883
# x12 = 0.5520442768423659, y12 = -0.271284559063792
# x13 = -0.7747663541641572, y13 = -0.851447453457522
# x14 = -0.9290780132713574, y14 = 0.2805804775789409
# x15 = 0.9616102075298518, y15 = -0.46928380078433585
# x16 = 0.6825465991531638, y16 = 0.9418785693816363
# x17 = -0.9316729851758045, y17 = -0.9649946916001122
# x18 = -0.5669583582664428, y18 = 0.33058915903773123
# x19 = -0.07059368605783956, y19 = 0.9209291354155618
# x20 = 0.4296082109981534, y20 = -0.1689920321191971
# x21 = 0.8815584269888828, y21 = 0.20005312138328346
# x22 = -0.3299069968178283, y22 = -0.9078329755619812
# x23 = 0.8769249949565117, y23 = -0.4057986608162294
# x24 = -0.741715931253661, y24 = -0.6703656315791646
# x25 = -0.746527213460292, y25 = -0.0782599700864417
# x26 = -0.4449630668526807, y26 = 0.6089005795612346
# x27 = 0.7491509084920223, y27 = 0.6568673470390853
# x28 = 0.6251528351504037, y28 = -0.8756212355944744
# x29 = -0.892599986657447, y29 = -0.8528525720948821
# x30 = 0.31226231922327896, y30 = 0.3220635842199653
# x31 = 0.05330544254534786, y31 = 0.9850393937672905
# x32 = -0.21462476433073885, y32 = -0.5660140736055095
# x33 = -0.9228861926151268, y33 = -0.13606442831339716
# x34 = 0.5915145297362123, y34 = 0.14704303190515455
# x35 = 0.3359781776574131, y35 = -0.3247086017436933
# x36 = -0.8022072946614229, y36 = 0.6807670591580097
# x37 = -0.08867183786398325, y37 = -0.3356553273722691
# x38 = -0.25532848138053854, y38 = -0.5687840376264575
# x39 = 0.3244079999203253, y39 = -0.07754069306548095
# x40 = 0.9534199798076577, y40 = -0.40455688686952973
# x41 = 0.8045420192005306, y41 = 0.1238919288428535
# x42 = -0.6950813497879169, y42 = -0.042207528571537756
# x43 = -0.8743201877614757, y43 = 0.886041064362245
# x44 = 0.24552184092662022, y44 = -0.08920147770421205
# x45 = -0.6838914305385366, y45 = 0.5890832097011816
# x46 = 0.6182909810232244, y46 = 0.19387423294465167
# x47 = 0.6607131825696784, y47 = 0.32940188793249026
# x48 = -0.5289048845845783, y48 = -0.0220176793279383
# x49 = 0.40867636839797017, y49 = -0.27769186235382004
# x50 = 0.8717519723199685, y50 = 0.8869606569930593
# x51 = -0.1785223571383101, y51 = 0.3899295607519353
# x52 = 0.1204441982253448, y52 = -0.3938565440130064
# x53 = -0.6615879852855377, y53 = -0.17474603115471132
# x54 = -0.8984419528281429, y54 = 0.438252916647659
# x55 = -0.2910136722601331, y55 = -0.7884250945312197
# x56 = 0.14480213837262013, y56 = -0.31470194645221783
# x57 = 0.28862629192702527, y57 = 0.6693776997737002
# x58 = -0.29687695752692256, y58 = 0.5413432184113778
# x59 = 0.37827774317408913, y59 = -0.057442946303752906
# x60 = -0.48611705485948575, y60 = -0.3609161046289129
# x61 = 0.4448381033433224, y61 = -0.46111624291859066
# x62 = 0.9896176452794576, y62 = -0.9056787587737687
# x63 = -0.8171629236273774, y63 = -0.027454435330415583
# x64 = -0.8512230592727565, y64 = -0.3160479937436338
# x65 = 0.8415809885783994, y65 = -0.9363796920111458
# x66 = 0.6282851867396975, y66 = 0.7477010237503336
# x67 = 0.22445831378428394, y67 = -0.1601902365836505
# x68 = -0.7999246738370525, y68 = -0.4538832035254201
# x69 = 0.3500359776052535, y69 = 0.10743889827886699
# x70 = -0.2537458956927152, y70 = 0.16654096435785282
# x71 = -0.4639478865619395, y71 = -0.524121099242626
# x72 = 0.134266589895923, y72 = -0.9966676956880645
# x73 = 0.7756744749104754, y73 = 0.6100397196759741
# x74 = -0.6089536883034921, y74 = 0.9005627000480161
# x75 = -0.3797405057085268, y75 = -0.6786647876500673
# x76 = -0.056898605591927165, y76 = -0.9889781067540189
# x77 = 0.996507464014661, y77 = -0.855418520660354
# x78 = -0.7616464345698635, y78 = -0.7192327548543884
# x79 = 0.672752253420307, y79 = 0.9292569868465712
# x80 = -0.903992768434118, y80 = 0.05209346232319789
# x81 = -0.4362972469536375, y81 = 0.9607854178992836
# x82 = -0.9922923390560219, y82 = 0.05272820385800858
# x83 = -0.31382816028138794, y83 = -0.5876169906967548
# x84 = -0.44128332527658554, y84 = 0.6308298714403997
# x85 = -0.07869434099121864, y85 = 0.30723578509746985
# x86 = -0.4004961616637237, y86 = -0.5747441757352463
# x87 = 0.17930190902619558, y87 = -0.2725426455112121
# x88 = -0.7608459233313192, y88 = 0.044293621938523264
# x89 = -0.92109697628228, y89 = 0.0011390609630550497
# x90 = 0.7009129271999035, y90 = -0.46528280880742834
# x91 = 0.6047975045523302, y91 = 0.9451137982891968
# x92 = 0.9364119697338145, y92 = 0.049390408928438045
# x93 = -0.12240384361710666, y93 = 0.5323800139317323
# x94 = -0.5202580541879951, y94 = 0.5900302197214558
# x95 = 0.649823421995521, y95 = -0.7924676976078422
# x96 = -0.8204333388879119, y96 = 0.926742149277799
# x97 = 0.7440394741797598, y97 = 0.6928351623807825
# x98 = -0.2224371582658422, y98 = 0.9416762075225718
# x99 = 0.3230965708940656, y99 = 0.46403332338405123
# x100 = -0.6372831044450129, y100 = 0.14310661239779354

# %%
# Uppgift 1e

import random as rnd
import math

tot_count = 0 # Variabeln för totalt kastade pilar
count = 0 # Variabeln för de pilarna inanför cirkeln


for i in range(100):
    x = rnd.uniform(-1,1)
    y = rnd.uniform(-1,1)
    d = math.sqrt(x**2+y**2) # Pythagorasats (med hjälp av import math)
    tot_count += 1 # Adderar med 1 för varje loop till variabeln tot_count
    if d <= 1: # Om distansen är mindre eller lika med 1 är den innanför cirkeln, eftersom radien är 1
        count += 1 # Adderar med 1 för varje loop till variabeln count

print(count/tot_count)
# Out:
# 0.78

# %%
# Uppgift 1f

import random as rnd
import math

tot_count = 0
count = 0


for i in range(100):
    x = rnd.uniform(-1,1)
    y = rnd.uniform(-1,1)
    d = math.sqrt(x**2+y**2) 
    tot_count += 1 
    if d <= 1:
        count += 1

s = count/tot_count # s = sanolikheten 

print(s*4) # Svaret blir som det blir för att man multiplicerar med 4
# Out:
# 3.28

# %%
# Uppgift 1g

import random as rnd
import math
import matplotlib.pyplot as plt # Använder denna modul för att kunna rita grafer

x_vals_outside = [ ] # En lista för x värdena utanför cirkeln
y_vals_outside = [ ]# En lista för y värdena utanför cirkeln
x_vals_inside = [ ] # En lista för x värdena innanför cirkeln
y_vals_inside = [ ] # En lista för y värdena innanför cirkeln

for i in range(100):
    x = rnd.uniform(-1,1)
    y = rnd.uniform(-1,1)
    d = math.sqrt(x**2+y**2)
    if d > 1:
        x_vals_outside.append(x) 
        y_vals_outside.append(y) # Vi sparar värdena för x och y när d är större än 1 i en lista för punkterna som är uanför cirkeln
    else:
        x_vals_inside.append(x) 
        y_vals_inside.append(y)# Vi sparar värdena för x och y när d är mindre än 1 i en lista för punkterna som är innanför cirkeln

plt.plot(x_vals_outside, y_vals_outside, '*r') # För att skriva ut punkterna för de värdena i den listan med en stjärna (*=En stjärna) och i röd färg (r=red)
plt.plot(x_vals_inside, y_vals_inside, '*g') # För att skriva ut punkterna för de värdena i den listan med em stjärna (*=En stjärna) i grön färg (g=green)
plt.show() # Skriver ut hela grafen

# %%
# Uppgift 1h

import random as rnd
import math
import matplotlib.pyplot as plt 

x_vals_outside = [ ] 
y_vals_outside = [ ]
x_vals_inside = [ ] 
y_vals_inside = [ ] 

for i in range(500):
    x = rnd.uniform(-10,10)
    y = rnd.uniform(-10,10)
    d = math.sqrt(x**2+y**2)
    if d > 10:
        x_vals_outside.append(x) 
        y_vals_outside.append(y) 
    else:
        x_vals_inside.append(x) 
        y_vals_inside.append(y)

plt.plot(x_vals_outside, y_vals_outside, '*r')
plt.plot(x_vals_inside, y_vals_inside, '*g')
plt.show()

# Oavsett vilken radie man har kommer grafen med prickarna se ungefär likadan ut, det som skiljer är värdena på x och y axeln (det blir fler värden)
# Om man skulle ha samma skalla på grafen hade punkterna haft större mellan rum mellan varandra

# Ju fler punkter man simulerar desto tätare sitter dem och formen blir då mer lik en cirkel
# Om man har få punkter kommer grafen att skilja sig mer (var punkterna ligger, hur långt ifrån varandra etc) varje gång man slumpar fram nya punkter jämfört med om man har många punkter
