# %%
# Uppgift 1a
import math # Använder denna modul för att kunna använda matte hjälpmedel
d = math.sqrt(0.5**2+0.5**2) # d = distance / math.sqrt = roten ur (med hjälp av import math)
print(d)
# Out:
# 0.7071067811865476

# %%
# Uppgift 1b
import math
d = math.sqrt(1**2+1**2) # d=distance
print(d)
# Out:
# 1.4142135623730951

# %%
# Uppgift 1c
import math
d = math.sqrt(0.5**2+(-0.5)**2) # d=distance
print(d)
# Out:
# 0.7071067811865476

# %%
# Uppgift 1d
import random as rnd # Använder denna modul för att kunna slumpa fram tal

n = 0 # Ett värde för variabeln som sedan ökas i for loopen

for i in range(100): # Hur många gånger loopen ska upprepas
    x = rnd.uniform(-1,1) # random generator
    y = rnd.uniform(-1,1) # random generator
    n += 1 # Vilken omgång det är, 1-100
    print(f"x{n} = {x}, y{n} = {y}") # f-string för att skriva ut text med variabel värdena
# Out:
# x1 = -0.6405050410872524, y1 = -0.22557817851788275
# x2 = -0.5239803930419509, y2 = -0.6200431871268655
# x3 = -0.004845413740122151, y3 = -0.5659410337466326
# x4 = 0.2956118517585815, y4 = 0.7509706710172825
# x5 = 0.2021399506696382, y5 = -0.3128118167568614
# x6 = -0.438158951724559, y6 = -0.36881664289961846
# x7 = -0.33180090071712964, y7 = -0.3927493023461759
# x8 = -0.9420257141828776, y8 = 0.801241970640719
# x9 = 0.6054597815082139, y9 = 0.9406321014791457
# x10 = -0.295259284534543, y10 = 0.5083212632983067
# x11 = -0.06886865977028611, y11 = 0.7791752845321556
# x12 = -0.7622129086342391, y12 = 0.7021127222151886
# x13 = -0.29279357801125694, y13 = -0.6887847431242144
# x14 = 0.2292903974498488, y14 = -0.08315021196854944
# x15 = -0.4092081591906658, y15 = 0.7293336497632865
# x16 = 0.8352514301508009, y16 = 0.889499702634297
# x17 = -0.5009883607719023, y17 = 0.8874569217467139
# x18 = -0.79252485071801, y18 = 0.9685688379621129
# x19 = 0.11728729864603449, y19 = -0.45460076705110786
# x20 = -0.7240490977723704, y20 = -0.6676068939407149
# x21 = 0.9897117372241651, y21 = 0.2242753630840908
# x22 = -0.26274390162938577, y22 = -0.40728503865885357
# x23 = 0.8237755670377107, y23 = -0.22662632159615126
# x24 = 0.2228774311724393, y24 = -0.8297617993225062
# x25 = -0.028329590118719494, y25 = 0.3686634849426673
# x26 = -0.46400039546821126, y26 = 0.6856597855676294
# x27 = -0.42335001488872614, y27 = -0.2594398901946895
# x28 = 0.9976717020265564, y28 = -0.5106541851342332
# x29 = -0.6979041564750659, y29 = -0.031238741244864032
# x30 = -0.9264128701560936, y30 = -0.8479631765430518
# x31 = -0.23948720129618994, y31 = -0.9413330623239624
# x32 = -0.4194384571869323, y32 = -0.7857821179678497
# x33 = -0.6661515781035805, y33 = 0.9030655394518778
# x34 = -0.7678968895184484, y34 = -0.9029191923999613
# x35 = 0.8872709368904426, y35 = -0.593568178157649
# x36 = -0.5953772292210702, y36 = 0.825374793936599
# x37 = 0.167342494292529, y37 = 0.6128101973027442
# x38 = 0.34925029844024813, y38 = 0.17497221712060962
# x39 = 0.9614777050041128, y39 = -0.5015082862677769
# x40 = 0.8550980787519105, y40 = 0.13582053155134433
# x41 = 0.45602765916894206, y41 = -0.27104995430166756
# x42 = 0.0018030047333856825, y42 = 0.06797117481186432
# x43 = 0.39211189096338694, y43 = 0.39107927786268415
# x44 = -0.8478092365389862, y44 = -0.9059875400499018
# x45 = 0.9235284984618144, y45 = 0.4762001674923717
# x46 = 0.21755667949192548, y46 = 0.7490557203484907
# x47 = 0.7428195266041953, y47 = 0.13153955163060527
# x48 = 0.1908102022630398, y48 = 0.2803076945367742
# x49 = 0.6876408325539554, y49 = -0.06333178215836455
# x50 = 0.30179496484325763, y50 = 0.34907876663422543
# x51 = -0.9655386983760275, y51 = -0.12348013847974837
# x52 = -0.4124844148136977, y52 = -0.9268418863012984
# x53 = 0.8230773604014574, y53 = 0.13212371052641392
# x54 = 0.4806563593817843, y54 = 0.1716737433811637
# x55 = -0.27767017454946163, y55 = 0.05481175716432385
# x56 = 0.6864556505148691, y56 = 0.9082179775636767
# x57 = 0.10576536006570358, y57 = 0.5284320166115075
# x58 = -0.18835451426988858, y58 = 0.5271189520176967
# x59 = -0.06359184836360288, y59 = 0.029701502884747377
# x60 = 0.26242352702053195, y60 = 0.3444838910256447
# x61 = 0.6170769196997936, y61 = -0.892697960045046
# x62 = 0.36919734004896365, y62 = 0.1500907633199864
# x63 = 0.23723377303602966, y63 = -0.6112285270041737
# x64 = 0.029045913215991925, y64 = 0.7231076991481542
# x65 = 0.5573392304333407, y65 = 0.5003019065860288
# x66 = -0.2755671538898474, y66 = 0.05110267156901527
# x67 = 0.3882767219822585, y67 = -0.5264938221929114
# x68 = -0.005801297879175271, y68 = -0.03800306732966696
# x69 = 0.78384580280992, y69 = 0.2843104958801652
# x70 = 0.8022603524450174, y70 = -0.5479996200788664
# x71 = -0.08457660283089075, y71 = 0.8712194303036553
# x72 = 0.30667412060816046, y72 = -0.17276285553778048
# x73 = -0.76756707150777, y73 = -0.13019413548149994
# x74 = 0.7362635822874903, y74 = 0.6260950393819353
# x75 = -0.22625951695614765, y75 = -0.5210841016218235
# x76 = -0.5065448122095211, y76 = 0.9648847231699724
# x77 = 0.17467659661027457, y77 = 0.06558919521447559
# x78 = -0.6018153503550756, y78 = 0.2753784003298292
# x79 = -0.1906186266684642, y79 = -0.8120325413546527
# x80 = -0.8067540043868835, y80 = -0.9512292300237082
# x81 = -0.4659506665770965, y81 = -0.21296613632286898
# x82 = -0.4823508368113094, y82 = -0.005034804880817756
# x83 = 0.12076728271437664, y83 = 0.6384711727097465
# x84 = -0.3507005383338928, y84 = 0.585776029239949
# x85 = 0.7991486965562438, y85 = 0.5204535769215126
# x86 = -0.5226211069092175, y86 = 0.3297256296898905
# x87 = -0.011422078193743745, y87 = 0.7694522290492003
# x88 = -0.10921312914000336, y88 = -0.39025145025583674
# x89 = -0.1340121099877094, y89 = -0.8432467402089203
# x90 = 0.8646875924296047, y90 = 0.8099523480420441
# x91 = -0.22583145221435896, y91 = -0.6853709294911046
# x92 = 0.6462264631009647, y92 = 0.6111101306033446
# x93 = -0.11895077464457837, y93 = 0.9695186302988585
# x94 = -0.7682223890165774, y94 = 0.6757356135478034
# x95 = -0.9539930138207369, y95 = 0.003546061166035619
# x96 = 0.3471312069870316, y96 = 0.6371061962588627
# x97 = 0.4194366566678269, y97 = 0.4849569545400638
# x98 = -0.45508357766305885, y98 = -0.7548505515512294
# x99 = -0.4906292253682041, y99 = -0.7619251694357159
# x100 = -0.12349388763982971, y100 = -0.009009236911742935

# %%
# Uppgift 1e

import random as rnd
import math

tot_count = 0 # Variabeln för totalt kastade pilar
count = 0 # Variabeln för de pilarna inanför cirkeln


for i in range(100):
    x = rnd.uniform(-1,1)
    y = rnd.uniform(-1,1)
    d = math.sqrt(x**2+y**2) # Pythagorasats (med hjälp av import math)
    tot_count += 1 # Adderar med 1 för varje loop till variabeln tot_count
    if d <= 1: # Om distansen är mindre eller lika med 1 är den innanför cirkeln, eftersom radien är 1
        count += 1 # Adderar med 1 för varje loop till variabeln count

print(count/tot_count)
# Out:
# 0.78

# %%
# Uppgift 1f

import random as rnd
import math

tot_count = 0
count = 0


for i in range(100):
    x = rnd.uniform(-1,1)
    y = rnd.uniform(-1,1)
    d = math.sqrt(x**2+y**2) 
    tot_count += 1 
    if d <= 1:
        count += 1

s = count/tot_count # s = sanolikheten 

print(s*4) # Svaret blir som det blir för att man multiplicerar med 4
# Out:
# 3.28

# %%
import random as rnd
import math
import matplotlib.pyplot as plt # Använder denna modul för att kunna rita grafer

d_vals_outside = [ ] # En lista för de värdena utanför cirkeln
d_vals_inside = [ ] # En lista för de värdena innanför cirkeln

for i in range(100):
    x = rnd.uniform(-1,1)
    y = rnd.uniform(-1,1)
    d = math.sqrt(x**2+y**2)
    if d > 1:
        d_vals_outside.append(d) # Vi sparar värdena för d som är utanför cirkeln i listan d_vals_outside
    else:
        d_vals_inside.append(d) # Vi sparar värdena för d som är innanför cirkeln i listan d_vals_inside

plt.plot(d_vals_outside, '*r') # För att skriva ut punkterna för de värdena i den listan med en stjärna (*=En stjärna) och i röd färg (r=red)
plt.plot(d_vals_inside, '*g') # För att skriva ut punkterna för de värdena i den listan med em stjärna (*=En stjärna) i grön färg (g=green)
plt.show() # Skriver ut hela grafen
